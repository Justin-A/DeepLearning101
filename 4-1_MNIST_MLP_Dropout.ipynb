# %%
''' 1. 모듈 임포트 '''
import numpy as np    
import matplotlib.pyplot as plt                        
import torch                                           
import torch.nn as nn                                  
import torch.nn.functional as F                        
from torchvision import transforms, datasets

# %%
''' 2. 딥러닝 모델을 설계할 때 활용하는 장비 확인 '''
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')

print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 1.5.0+cu101  Device: cuda

# %%
BATCH_SIZE = 32   
EPOCHS = 30

# %%
''' 3. MNIST 데이터 다운로드 (Train set, Test set 분리하기) '''
train_dataset = datasets.MNIST(root = "../data/MNIST",                    
                               train = True,
                               download = True,
                               transform = transforms.ToTensor())

test_dataset = datasets.MNIST(root = '../data/MNIST',                     
                              train = False,
                              transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,    
                                           batch_size = BATCH_SIZE,
                                           shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,      
                                          batch_size = BATCH_SIZE, 
                                          shuffle = False)

# %%
''' 4. 데이터 확인하기 (1) '''
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 1, 28, 28]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
''' 4. 데이터 확인하기 (2) '''
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))

for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(X_train[i, :, :, :].numpy().reshape(28, 28), cmap = "gray_r")
    plt.title('Class: ' + str(y_train[i].item()))

# %%
''' 5. MLP (Multi Layer Perceptron) 모델 설계하기 '''
class Net(nn.Module):                       
    def __init__(self):                     
        super(Net, self).__init__()         
        self.fc1 = nn.Linear(28 * 28, 512)  
        self.fc2 = nn.Linear(512, 256)      
        self.fc3 = nn.Linear(256, 10)       
        self.dropout_prob = 0.5
    
    def forward(self, x):                   
        x = x.view(-1, 28 * 28)             
        x = self.fc1(x)                     
        x = F.sigmoid(x)                    
        x = F.dropout(x, training = self.training, p = self.dropout_prob)
        x = self.fc2(x)                     
        x = F.sigmoid(x)                    
        x = F.dropout(x, training = self.training, p = self.dropout_prob)
        x = self.fc3(x)                     
        x = F.log_softmax(x, dim = 1)       
        return x

# %%
''' 6. Optimizer, Objective Function 설정하기 '''
model = Net().to(DEVICE)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
''' 7. MLP 학습, Test 성능 확인하는 함수 정의 '''
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image), 
                len(train_loader.dataset), 100. * batch_idx / len(train_loader), 
                loss.item()))

# %%
def evaluate(model, valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            valid_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    
    valid_loss /= len(valid_loader.dataset)
    valid_accuracy = 100. * correct / len(valid_loader.dataset)
    return valid_loss, valid_accuracy

# %%
''' 8. MLP 학습 실행 '''
''' 9. EPOCH 별 Test set Loss 및 Test set Accuracy 확인하기 '''
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    valid_loss, valid_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tValidation Loss: {:.4f}, \tValidation Accuracy: {:.2f} % \n".format(
        epoch, valid_loss, valid_accuracy))
# Out:
# /home/justin/101/lib/python3.6/site-packages/torch/nn/functional.py:1569: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train Epoch: 1 [0/60000 (0%)]	Train Loss: 2.443595
# Train Epoch: 1 [6400/60000 (11%)]	Train Loss: 2.306917
# Train Epoch: 1 [12800/60000 (21%)]	Train Loss: 2.284744
# Train Epoch: 1 [19200/60000 (32%)]	Train Loss: 2.331300
# Train Epoch: 1 [25600/60000 (43%)]	Train Loss: 2.398490
# Train Epoch: 1 [32000/60000 (53%)]	Train Loss: 2.310748
# Train Epoch: 1 [38400/60000 (64%)]	Train Loss: 2.361763
# Train Epoch: 1 [44800/60000 (75%)]	Train Loss: 2.324190
# Train Epoch: 1 [51200/60000 (85%)]	Train Loss: 2.328741
# Train Epoch: 1 [57600/60000 (96%)]	Train Loss: 2.337294
#
# [EPOCH: 1], 	Validation Loss: 0.0713, 	Validation Accuracy: 11.35 %
#
# Train Epoch: 2 [0/60000 (0%)]	Train Loss: 2.345022
# Train Epoch: 2 [6400/60000 (11%)]	Train Loss: 2.230997
# Train Epoch: 2 [12800/60000 (21%)]	Train Loss: 2.308092
# Train Epoch: 2 [19200/60000 (32%)]	Train Loss: 2.272178
# Train Epoch: 2 [25600/60000 (43%)]	Train Loss: 2.239508
# Train Epoch: 2 [32000/60000 (53%)]	Train Loss: 2.299011
# Train Epoch: 2 [38400/60000 (64%)]	Train Loss: 2.213306
# Train Epoch: 2 [44800/60000 (75%)]	Train Loss: 2.232458
# Train Epoch: 2 [51200/60000 (85%)]	Train Loss: 2.242869
# Train Epoch: 2 [57600/60000 (96%)]	Train Loss: 2.153414
#
# [EPOCH: 2], 	Validation Loss: 0.0649, 	Validation Accuracy: 43.72 %
#
# Train Epoch: 3 [0/60000 (0%)]	Train Loss: 2.027799
# Train Epoch: 3 [6400/60000 (11%)]	Train Loss: 2.219499
# Train Epoch: 3 [12800/60000 (21%)]	Train Loss: 1.959487
# Train Epoch: 3 [19200/60000 (32%)]	Train Loss: 1.761758
# Train Epoch: 3 [25600/60000 (43%)]	Train Loss: 1.856331
# Train Epoch: 3 [32000/60000 (53%)]	Train Loss: 1.792096
# Train Epoch: 3 [38400/60000 (64%)]	Train Loss: 1.785113
# Train Epoch: 3 [44800/60000 (75%)]	Train Loss: 1.585093
# Train Epoch: 3 [51200/60000 (85%)]	Train Loss: 1.668544
# Train Epoch: 3 [57600/60000 (96%)]	Train Loss: 1.421518
#
# [EPOCH: 3], 	Validation Loss: 0.0406, 	Validation Accuracy: 57.50 %
#
# Train Epoch: 4 [0/60000 (0%)]	Train Loss: 1.496686
# Train Epoch: 4 [6400/60000 (11%)]	Train Loss: 1.317165
# Train Epoch: 4 [12800/60000 (21%)]	Train Loss: 1.425944
# Train Epoch: 4 [19200/60000 (32%)]	Train Loss: 1.236844
# Train Epoch: 4 [25600/60000 (43%)]	Train Loss: 1.356734
# Train Epoch: 4 [32000/60000 (53%)]	Train Loss: 1.236128
# Train Epoch: 4 [38400/60000 (64%)]	Train Loss: 1.064029
# Train Epoch: 4 [44800/60000 (75%)]	Train Loss: 1.275715
# Train Epoch: 4 [51200/60000 (85%)]	Train Loss: 1.096477
# Train Epoch: 4 [57600/60000 (96%)]	Train Loss: 1.255962
#
# [EPOCH: 4], 	Validation Loss: 0.0283, 	Validation Accuracy: 70.24 %
#
# Train Epoch: 5 [0/60000 (0%)]	Train Loss: 0.943012
# Train Epoch: 5 [6400/60000 (11%)]	Train Loss: 1.016608
# Train Epoch: 5 [12800/60000 (21%)]	Train Loss: 1.052414
# Train Epoch: 5 [19200/60000 (32%)]	Train Loss: 1.049929
# Train Epoch: 5 [25600/60000 (43%)]	Train Loss: 0.958718
# Train Epoch: 5 [32000/60000 (53%)]	Train Loss: 1.042972
# Train Epoch: 5 [38400/60000 (64%)]	Train Loss: 1.243785
# Train Epoch: 5 [44800/60000 (75%)]	Train Loss: 0.855842
# Train Epoch: 5 [51200/60000 (85%)]	Train Loss: 0.674987
# Train Epoch: 5 [57600/60000 (96%)]	Train Loss: 0.838875
#
# [EPOCH: 5], 	Validation Loss: 0.0238, 	Validation Accuracy: 75.15 %
#
# Train Epoch: 6 [0/60000 (0%)]	Train Loss: 0.648998
# Train Epoch: 6 [6400/60000 (11%)]	Train Loss: 0.699418
# Train Epoch: 6 [12800/60000 (21%)]	Train Loss: 0.749060
# Train Epoch: 6 [19200/60000 (32%)]	Train Loss: 0.769235
# Train Epoch: 6 [25600/60000 (43%)]	Train Loss: 0.649447
# Train Epoch: 6 [32000/60000 (53%)]	Train Loss: 1.023376
# Train Epoch: 6 [38400/60000 (64%)]	Train Loss: 0.904093
# Train Epoch: 6 [44800/60000 (75%)]	Train Loss: 0.877338
# Train Epoch: 6 [51200/60000 (85%)]	Train Loss: 0.806043
# Train Epoch: 6 [57600/60000 (96%)]	Train Loss: 0.907876
#
# [EPOCH: 6], 	Validation Loss: 0.0207, 	Validation Accuracy: 79.64 %
#
# Train Epoch: 7 [0/60000 (0%)]	Train Loss: 0.886687
# Train Epoch: 7 [6400/60000 (11%)]	Train Loss: 0.716929
# Train Epoch: 7 [12800/60000 (21%)]	Train Loss: 0.782510
# Train Epoch: 7 [19200/60000 (32%)]	Train Loss: 0.553151
# Train Epoch: 7 [25600/60000 (43%)]	Train Loss: 0.915380
# Train Epoch: 7 [32000/60000 (53%)]	Train Loss: 0.816685
# Train Epoch: 7 [38400/60000 (64%)]	Train Loss: 0.448693
# Train Epoch: 7 [44800/60000 (75%)]	Train Loss: 0.667646
# Train Epoch: 7 [51200/60000 (85%)]	Train Loss: 0.975542
# Train Epoch: 7 [57600/60000 (96%)]	Train Loss: 0.367167
#
# [EPOCH: 7], 	Validation Loss: 0.0181, 	Validation Accuracy: 82.92 %
#
# Train Epoch: 8 [0/60000 (0%)]	Train Loss: 0.529852
# Train Epoch: 8 [6400/60000 (11%)]	Train Loss: 0.969545
# Train Epoch: 8 [12800/60000 (21%)]	Train Loss: 0.417237
# Train Epoch: 8 [19200/60000 (32%)]	Train Loss: 0.895031
# Train Epoch: 8 [25600/60000 (43%)]	Train Loss: 0.434071
# Train Epoch: 8 [32000/60000 (53%)]	Train Loss: 0.699625
# Train Epoch: 8 [38400/60000 (64%)]	Train Loss: 0.827894
# Train Epoch: 8 [44800/60000 (75%)]	Train Loss: 0.412105
# Train Epoch: 8 [51200/60000 (85%)]	Train Loss: 0.447729
# Train Epoch: 8 [57600/60000 (96%)]	Train Loss: 0.758878
#
# [EPOCH: 8], 	Validation Loss: 0.0160, 	Validation Accuracy: 84.82 %
#
# Train Epoch: 9 [0/60000 (0%)]	Train Loss: 0.360836
# Train Epoch: 9 [6400/60000 (11%)]	Train Loss: 0.347332
# Train Epoch: 9 [12800/60000 (21%)]	Train Loss: 0.395157
# Train Epoch: 9 [19200/60000 (32%)]	Train Loss: 0.775932
# Train Epoch: 9 [25600/60000 (43%)]	Train Loss: 0.974610
# Train Epoch: 9 [32000/60000 (53%)]	Train Loss: 0.519310
# Train Epoch: 9 [38400/60000 (64%)]	Train Loss: 0.305372
# Train Epoch: 9 [44800/60000 (75%)]	Train Loss: 1.018816
# Train Epoch: 9 [51200/60000 (85%)]	Train Loss: 0.613294
# Train Epoch: 9 [57600/60000 (96%)]	Train Loss: 0.490974
#
# [EPOCH: 9], 	Validation Loss: 0.0147, 	Validation Accuracy: 86.05 %
#
# Train Epoch: 10 [0/60000 (0%)]	Train Loss: 0.786910
# Train Epoch: 10 [6400/60000 (11%)]	Train Loss: 0.558106
# Train Epoch: 10 [12800/60000 (21%)]	Train Loss: 0.523746
# Train Epoch: 10 [19200/60000 (32%)]	Train Loss: 0.641436
# Train Epoch: 10 [25600/60000 (43%)]	Train Loss: 0.716053
# Train Epoch: 10 [32000/60000 (53%)]	Train Loss: 0.568971
# Train Epoch: 10 [38400/60000 (64%)]	Train Loss: 0.790743
# Train Epoch: 10 [44800/60000 (75%)]	Train Loss: 0.579865
# Train Epoch: 10 [51200/60000 (85%)]	Train Loss: 0.371114
# Train Epoch: 10 [57600/60000 (96%)]	Train Loss: 0.540374
#
# [EPOCH: 10], 	Validation Loss: 0.0138, 	Validation Accuracy: 87.02 %
#
# Train Epoch: 11 [0/60000 (0%)]	Train Loss: 0.500870
# Train Epoch: 11 [6400/60000 (11%)]	Train Loss: 0.485961
# Train Epoch: 11 [12800/60000 (21%)]	Train Loss: 0.479498
# Train Epoch: 11 [19200/60000 (32%)]	Train Loss: 0.405346
# Train Epoch: 11 [25600/60000 (43%)]	Train Loss: 0.656270
# Train Epoch: 11 [32000/60000 (53%)]	Train Loss: 0.863465
# Train Epoch: 11 [38400/60000 (64%)]	Train Loss: 0.436706
# Train Epoch: 11 [44800/60000 (75%)]	Train Loss: 0.510115
# Train Epoch: 11 [51200/60000 (85%)]	Train Loss: 0.578121
# Train Epoch: 11 [57600/60000 (96%)]	Train Loss: 0.743477
#
# [EPOCH: 11], 	Validation Loss: 0.0131, 	Validation Accuracy: 87.36 %
#
# Train Epoch: 12 [0/60000 (0%)]	Train Loss: 0.460245
# Train Epoch: 12 [6400/60000 (11%)]	Train Loss: 0.387064
# Train Epoch: 12 [12800/60000 (21%)]	Train Loss: 0.671191
# Train Epoch: 12 [19200/60000 (32%)]	Train Loss: 0.507784
# Train Epoch: 12 [25600/60000 (43%)]	Train Loss: 0.471719
# Train Epoch: 12 [32000/60000 (53%)]	Train Loss: 0.426498
# Train Epoch: 12 [38400/60000 (64%)]	Train Loss: 0.402183
# Train Epoch: 12 [44800/60000 (75%)]	Train Loss: 0.438506
# Train Epoch: 12 [51200/60000 (85%)]	Train Loss: 0.419954
# Train Epoch: 12 [57600/60000 (96%)]	Train Loss: 0.426962
#
# [EPOCH: 12], 	Validation Loss: 0.0125, 	Validation Accuracy: 88.10 %
#
# Train Epoch: 13 [0/60000 (0%)]	Train Loss: 0.650839
# Train Epoch: 13 [6400/60000 (11%)]	Train Loss: 0.944583
# Train Epoch: 13 [12800/60000 (21%)]	Train Loss: 0.292257
# Train Epoch: 13 [19200/60000 (32%)]	Train Loss: 0.437843
# Train Epoch: 13 [25600/60000 (43%)]	Train Loss: 0.609481
# Train Epoch: 13 [32000/60000 (53%)]	Train Loss: 0.293957
# Train Epoch: 13 [38400/60000 (64%)]	Train Loss: 0.682871
# Train Epoch: 13 [44800/60000 (75%)]	Train Loss: 0.544321
# Train Epoch: 13 [51200/60000 (85%)]	Train Loss: 0.504481
# Train Epoch: 13 [57600/60000 (96%)]	Train Loss: 0.523092
#
# [EPOCH: 13], 	Validation Loss: 0.0120, 	Validation Accuracy: 88.53 %
#
# Train Epoch: 14 [0/60000 (0%)]	Train Loss: 0.327728
# Train Epoch: 14 [6400/60000 (11%)]	Train Loss: 0.761639
# Train Epoch: 14 [12800/60000 (21%)]	Train Loss: 0.912828
# Train Epoch: 14 [19200/60000 (32%)]	Train Loss: 0.363859
# Train Epoch: 14 [25600/60000 (43%)]	Train Loss: 0.416864
# Train Epoch: 14 [32000/60000 (53%)]	Train Loss: 0.776007
# Train Epoch: 14 [38400/60000 (64%)]	Train Loss: 0.690409
# Train Epoch: 14 [44800/60000 (75%)]	Train Loss: 0.409702
# Train Epoch: 14 [51200/60000 (85%)]	Train Loss: 0.482720
# Train Epoch: 14 [57600/60000 (96%)]	Train Loss: 0.729444
#
# [EPOCH: 14], 	Validation Loss: 0.0116, 	Validation Accuracy: 89.06 %
#
# Train Epoch: 15 [0/60000 (0%)]	Train Loss: 0.702471
# Train Epoch: 15 [6400/60000 (11%)]	Train Loss: 0.300806
# Train Epoch: 15 [12800/60000 (21%)]	Train Loss: 0.562288
# Train Epoch: 15 [19200/60000 (32%)]	Train Loss: 0.389304
# Train Epoch: 15 [25600/60000 (43%)]	Train Loss: 0.504873
# Train Epoch: 15 [32000/60000 (53%)]	Train Loss: 0.335015
# Train Epoch: 15 [38400/60000 (64%)]	Train Loss: 0.471779
# Train Epoch: 15 [44800/60000 (75%)]	Train Loss: 0.529083
# Train Epoch: 15 [51200/60000 (85%)]	Train Loss: 0.519025
# Train Epoch: 15 [57600/60000 (96%)]	Train Loss: 0.419493
#
# [EPOCH: 15], 	Validation Loss: 0.0112, 	Validation Accuracy: 89.13 %
#
# Train Epoch: 16 [0/60000 (0%)]	Train Loss: 0.630326
# Train Epoch: 16 [6400/60000 (11%)]	Train Loss: 0.662830
# Train Epoch: 16 [12800/60000 (21%)]	Train Loss: 0.567910
# Train Epoch: 16 [19200/60000 (32%)]	Train Loss: 0.319716
# Train Epoch: 16 [25600/60000 (43%)]	Train Loss: 0.855289
# Train Epoch: 16 [32000/60000 (53%)]	Train Loss: 0.657597
# Train Epoch: 16 [38400/60000 (64%)]	Train Loss: 0.471382
# Train Epoch: 16 [44800/60000 (75%)]	Train Loss: 0.433179
# Train Epoch: 16 [51200/60000 (85%)]	Train Loss: 0.277671
# Train Epoch: 16 [57600/60000 (96%)]	Train Loss: 0.540517
#
# [EPOCH: 16], 	Validation Loss: 0.0109, 	Validation Accuracy: 89.61 %
#
# Train Epoch: 17 [0/60000 (0%)]	Train Loss: 0.953188
# Train Epoch: 17 [6400/60000 (11%)]	Train Loss: 0.549383
# Train Epoch: 17 [12800/60000 (21%)]	Train Loss: 0.589893
# Train Epoch: 17 [19200/60000 (32%)]	Train Loss: 0.406484
# Train Epoch: 17 [25600/60000 (43%)]	Train Loss: 0.638515
# Train Epoch: 17 [32000/60000 (53%)]	Train Loss: 0.508242
# Train Epoch: 17 [38400/60000 (64%)]	Train Loss: 0.448592
# Train Epoch: 17 [44800/60000 (75%)]	Train Loss: 0.297411
# Train Epoch: 17 [51200/60000 (85%)]	Train Loss: 0.573070
# Train Epoch: 17 [57600/60000 (96%)]	Train Loss: 0.840697
#
# [EPOCH: 17], 	Validation Loss: 0.0107, 	Validation Accuracy: 89.66 %
#
# Train Epoch: 18 [0/60000 (0%)]	Train Loss: 0.346829
# Train Epoch: 18 [6400/60000 (11%)]	Train Loss: 0.447882
# Train Epoch: 18 [12800/60000 (21%)]	Train Loss: 0.550058
# Train Epoch: 18 [19200/60000 (32%)]	Train Loss: 0.395333
# Train Epoch: 18 [25600/60000 (43%)]	Train Loss: 0.450673
# Train Epoch: 18 [32000/60000 (53%)]	Train Loss: 0.223894
# Train Epoch: 18 [38400/60000 (64%)]	Train Loss: 0.637064
# Train Epoch: 18 [44800/60000 (75%)]	Train Loss: 0.273186
# Train Epoch: 18 [51200/60000 (85%)]	Train Loss: 0.252691
# Train Epoch: 18 [57600/60000 (96%)]	Train Loss: 0.505192
#
# [EPOCH: 18], 	Validation Loss: 0.0104, 	Validation Accuracy: 90.12 %
#
# Train Epoch: 19 [0/60000 (0%)]	Train Loss: 0.332592
# Train Epoch: 19 [6400/60000 (11%)]	Train Loss: 0.578516
# Train Epoch: 19 [12800/60000 (21%)]	Train Loss: 0.584251
# Train Epoch: 19 [19200/60000 (32%)]	Train Loss: 0.592320
# Train Epoch: 19 [25600/60000 (43%)]	Train Loss: 0.236812
# Train Epoch: 19 [32000/60000 (53%)]	Train Loss: 0.523330
# Train Epoch: 19 [38400/60000 (64%)]	Train Loss: 0.206872
# Train Epoch: 19 [44800/60000 (75%)]	Train Loss: 0.611785
# Train Epoch: 19 [51200/60000 (85%)]	Train Loss: 0.298777
# Train Epoch: 19 [57600/60000 (96%)]	Train Loss: 0.466196
#
# [EPOCH: 19], 	Validation Loss: 0.0102, 	Validation Accuracy: 90.29 %
#
# Train Epoch: 20 [0/60000 (0%)]	Train Loss: 0.587880
# Train Epoch: 20 [6400/60000 (11%)]	Train Loss: 0.437878
# Train Epoch: 20 [12800/60000 (21%)]	Train Loss: 0.432046
# Train Epoch: 20 [19200/60000 (32%)]	Train Loss: 0.692101
# Train Epoch: 20 [25600/60000 (43%)]	Train Loss: 0.231948
# Train Epoch: 20 [32000/60000 (53%)]	Train Loss: 0.211741
# Train Epoch: 20 [38400/60000 (64%)]	Train Loss: 0.366920
# Train Epoch: 20 [44800/60000 (75%)]	Train Loss: 0.293945
# Train Epoch: 20 [51200/60000 (85%)]	Train Loss: 0.413248
# Train Epoch: 20 [57600/60000 (96%)]	Train Loss: 0.692975
#
# [EPOCH: 20], 	Validation Loss: 0.0099, 	Validation Accuracy: 90.42 %
#
# Train Epoch: 21 [0/60000 (0%)]	Train Loss: 0.288637
# Train Epoch: 21 [6400/60000 (11%)]	Train Loss: 0.402500
# Train Epoch: 21 [12800/60000 (21%)]	Train Loss: 0.394769
# Train Epoch: 21 [19200/60000 (32%)]	Train Loss: 0.370382
# Train Epoch: 21 [25600/60000 (43%)]	Train Loss: 0.505611
# Train Epoch: 21 [32000/60000 (53%)]	Train Loss: 0.167085
# Train Epoch: 21 [38400/60000 (64%)]	Train Loss: 0.413457
# Train Epoch: 21 [44800/60000 (75%)]	Train Loss: 0.282580
# Train Epoch: 21 [51200/60000 (85%)]	Train Loss: 0.440348
# Train Epoch: 21 [57600/60000 (96%)]	Train Loss: 0.353933
#
# [EPOCH: 21], 	Validation Loss: 0.0097, 	Validation Accuracy: 90.64 %
#
# Train Epoch: 22 [0/60000 (0%)]	Train Loss: 0.477598
# Train Epoch: 22 [6400/60000 (11%)]	Train Loss: 0.257437
# Train Epoch: 22 [12800/60000 (21%)]	Train Loss: 0.509408
# Train Epoch: 22 [19200/60000 (32%)]	Train Loss: 0.412935
# Train Epoch: 22 [25600/60000 (43%)]	Train Loss: 0.778631
# Train Epoch: 22 [32000/60000 (53%)]	Train Loss: 0.314731
# Train Epoch: 22 [38400/60000 (64%)]	Train Loss: 0.316854
# Train Epoch: 22 [44800/60000 (75%)]	Train Loss: 0.514714
# Train Epoch: 22 [51200/60000 (85%)]	Train Loss: 0.547550
# Train Epoch: 22 [57600/60000 (96%)]	Train Loss: 0.384672
#
# [EPOCH: 22], 	Validation Loss: 0.0095, 	Validation Accuracy: 90.82 %
#
# Train Epoch: 23 [0/60000 (0%)]	Train Loss: 0.441813
# Train Epoch: 23 [6400/60000 (11%)]	Train Loss: 0.295056
# Train Epoch: 23 [12800/60000 (21%)]	Train Loss: 0.297045
# Train Epoch: 23 [19200/60000 (32%)]	Train Loss: 0.077142
# Train Epoch: 23 [25600/60000 (43%)]	Train Loss: 0.274210
# Train Epoch: 23 [32000/60000 (53%)]	Train Loss: 0.453862
# Train Epoch: 23 [38400/60000 (64%)]	Train Loss: 0.277947
# Train Epoch: 23 [44800/60000 (75%)]	Train Loss: 0.490920
# Train Epoch: 23 [51200/60000 (85%)]	Train Loss: 0.195429
# Train Epoch: 23 [57600/60000 (96%)]	Train Loss: 0.215154
#
# [EPOCH: 23], 	Validation Loss: 0.0094, 	Validation Accuracy: 90.91 %
#
# Train Epoch: 24 [0/60000 (0%)]	Train Loss: 0.552420
# Train Epoch: 24 [6400/60000 (11%)]	Train Loss: 0.373641
# Train Epoch: 24 [12800/60000 (21%)]	Train Loss: 0.293706
# Train Epoch: 24 [19200/60000 (32%)]	Train Loss: 0.214191
# Train Epoch: 24 [25600/60000 (43%)]	Train Loss: 0.434950
# Train Epoch: 24 [32000/60000 (53%)]	Train Loss: 0.610680
# Train Epoch: 24 [38400/60000 (64%)]	Train Loss: 0.419323
# Train Epoch: 24 [44800/60000 (75%)]	Train Loss: 0.248074
# Train Epoch: 24 [51200/60000 (85%)]	Train Loss: 0.237203
# Train Epoch: 24 [57600/60000 (96%)]	Train Loss: 0.436927
#
# [EPOCH: 24], 	Validation Loss: 0.0092, 	Validation Accuracy: 91.19 %
#
# Train Epoch: 25 [0/60000 (0%)]	Train Loss: 0.476227
# Train Epoch: 25 [6400/60000 (11%)]	Train Loss: 0.708169
# Train Epoch: 25 [12800/60000 (21%)]	Train Loss: 0.273101
# Train Epoch: 25 [19200/60000 (32%)]	Train Loss: 0.465060
# Train Epoch: 25 [25600/60000 (43%)]	Train Loss: 0.464002
# Train Epoch: 25 [32000/60000 (53%)]	Train Loss: 0.194476
# Train Epoch: 25 [38400/60000 (64%)]	Train Loss: 0.269097
# Train Epoch: 25 [44800/60000 (75%)]	Train Loss: 0.383882
# Train Epoch: 25 [51200/60000 (85%)]	Train Loss: 0.481893
# Train Epoch: 25 [57600/60000 (96%)]	Train Loss: 0.549110
#
# [EPOCH: 25], 	Validation Loss: 0.0090, 	Validation Accuracy: 91.25 %
#
# Train Epoch: 26 [0/60000 (0%)]	Train Loss: 0.313704
# Train Epoch: 26 [6400/60000 (11%)]	Train Loss: 0.451202
# Train Epoch: 26 [12800/60000 (21%)]	Train Loss: 0.485282
# Train Epoch: 26 [19200/60000 (32%)]	Train Loss: 0.314181
# Train Epoch: 26 [25600/60000 (43%)]	Train Loss: 0.332021
# Train Epoch: 26 [32000/60000 (53%)]	Train Loss: 0.363784
# Train Epoch: 26 [38400/60000 (64%)]	Train Loss: 0.335449
# Train Epoch: 26 [44800/60000 (75%)]	Train Loss: 0.190716
# Train Epoch: 26 [51200/60000 (85%)]	Train Loss: 1.049758
# Train Epoch: 26 [57600/60000 (96%)]	Train Loss: 0.450458
#
# [EPOCH: 26], 	Validation Loss: 0.0089, 	Validation Accuracy: 91.39 %
#
# Train Epoch: 27 [0/60000 (0%)]	Train Loss: 0.356935
# Train Epoch: 27 [6400/60000 (11%)]	Train Loss: 0.358895
# Train Epoch: 27 [12800/60000 (21%)]	Train Loss: 0.466122
# Train Epoch: 27 [19200/60000 (32%)]	Train Loss: 0.593584
# Train Epoch: 27 [25600/60000 (43%)]	Train Loss: 0.197643
# Train Epoch: 27 [32000/60000 (53%)]	Train Loss: 0.574012
# Train Epoch: 27 [38400/60000 (64%)]	Train Loss: 0.716893
# Train Epoch: 27 [44800/60000 (75%)]	Train Loss: 0.199818
# Train Epoch: 27 [51200/60000 (85%)]	Train Loss: 0.247297
# Train Epoch: 27 [57600/60000 (96%)]	Train Loss: 0.243175
#
# [EPOCH: 27], 	Validation Loss: 0.0087, 	Validation Accuracy: 91.58 %
#
# Train Epoch: 28 [0/60000 (0%)]	Train Loss: 0.389034
# Train Epoch: 28 [6400/60000 (11%)]	Train Loss: 0.434587
# Train Epoch: 28 [12800/60000 (21%)]	Train Loss: 0.218894
# Train Epoch: 28 [19200/60000 (32%)]	Train Loss: 0.452186
# Train Epoch: 28 [25600/60000 (43%)]	Train Loss: 0.184010
# Train Epoch: 28 [32000/60000 (53%)]	Train Loss: 0.342697
# Train Epoch: 28 [38400/60000 (64%)]	Train Loss: 0.260948
# Train Epoch: 28 [44800/60000 (75%)]	Train Loss: 0.119302
# Train Epoch: 28 [51200/60000 (85%)]	Train Loss: 0.564267
# Train Epoch: 28 [57600/60000 (96%)]	Train Loss: 0.356042
#
# [EPOCH: 28], 	Validation Loss: 0.0086, 	Validation Accuracy: 91.57 %
#
# Train Epoch: 29 [0/60000 (0%)]	Train Loss: 0.151298
# Train Epoch: 29 [6400/60000 (11%)]	Train Loss: 0.131020
# Train Epoch: 29 [12800/60000 (21%)]	Train Loss: 0.159634
# Train Epoch: 29 [19200/60000 (32%)]	Train Loss: 0.368065
# Train Epoch: 29 [25600/60000 (43%)]	Train Loss: 0.463066
# Train Epoch: 29 [32000/60000 (53%)]	Train Loss: 0.396453
# Train Epoch: 29 [38400/60000 (64%)]	Train Loss: 0.254556
# Train Epoch: 29 [44800/60000 (75%)]	Train Loss: 0.475175
# Train Epoch: 29 [51200/60000 (85%)]	Train Loss: 0.292306
# Train Epoch: 29 [57600/60000 (96%)]	Train Loss: 0.183397
#
# [EPOCH: 29], 	Validation Loss: 0.0085, 	Validation Accuracy: 91.74 %
#
# Train Epoch: 30 [0/60000 (0%)]	Train Loss: 0.340740
# Train Epoch: 30 [6400/60000 (11%)]	Train Loss: 0.495352
# Train Epoch: 30 [12800/60000 (21%)]	Train Loss: 0.327934
# Train Epoch: 30 [19200/60000 (32%)]	Train Loss: 0.418135
# Train Epoch: 30 [25600/60000 (43%)]	Train Loss: 0.355742
# Train Epoch: 30 [32000/60000 (53%)]	Train Loss: 0.468929
# Train Epoch: 30 [38400/60000 (64%)]	Train Loss: 0.653949
# Train Epoch: 30 [44800/60000 (75%)]	Train Loss: 0.195051
# Train Epoch: 30 [51200/60000 (85%)]	Train Loss: 0.382733
# Train Epoch: 30 [57600/60000 (96%)]	Train Loss: 0.369352
#
# [EPOCH: 30], 	Validation Loss: 0.0084, 	Validation Accuracy: 91.76 %
