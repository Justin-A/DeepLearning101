# %%
''' 1. 모듈 임포트 '''
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms, datasets

# %%
''' 2. 딥러닝 모델을 설계할 때 활용하는 장비 확인 '''
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')

print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 1.5.0+cu101  Device: cuda

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %%
''' 3. CIFAR10 데이터 다운로드 '''
train_dataset = datasets.CIFAR10(root = "../data/CIFAR_10",
                                  train = True,
                                  download = True,
                                  transform = transforms.ToTensor())

test_dataset = datasets.CIFAR10(root = "../data/CIFAR_10",
                                train = False,
                                transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                            batch_size = BATCH_SIZE,
                                            shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/CIFAR_10/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../data/CIFAR_10/cifar-10-python.tar.gz to ../data/CIFAR_10

# %%
''' 4. 데이터 확인하기 (1) '''
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 3, 32, 32]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
''' 4. 데이터 확인하기 (2) '''
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))

for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(np.transpose(X_train[i], (1, 2, 0)))
    plt.title('Class: ' + str(y_train[i].item()))

# %%
''' 5. MLP (Multi Layer Perceptron) 모델 설계하기 '''
class Net(nn.Module):                             # (1)
    def __init__(self):                           # (2)
        super(Net, self).__init__()               # (3)
        self.fc1 = nn.Linear(32 * 32 * 3, 512)    # (4)
        self.fc2 = nn.Linear(512, 256)            # (5)
        self.fc3 = nn.Linear(256, 10)             # (6)
    
    def forward(self, x):                         # (7)
        x = x.view(-1, 32 * 32 * 3)               # (8)
        x = self.fc1(x)                           # (9)
        x = F.relu(x)                             # (10)
        x = self.fc2(x)                           # (11)
        x = F.relu(x)                             # (12)
        x = self.fc3(x)                           # (13)
        x = F.log_softmax(x, dim = 1)             # (14)
        return x                                  # (15)

# %%
''' 6. Optimizer, Objective Function 설정하기 '''
model = Net().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=3072, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
''' 7. MLP 학습, Test 성능 확인하는 함수 정의 '''
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image), 
                len(train_loader.dataset), 100. * batch_idx / len(train_loader), 
                loss.item()))

# %%
def evaluate(model, valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            valid_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    
    valid_loss /= len(valid_loader.dataset)
    valid_accuracy = 100. * correct / len(valid_loader.dataset)
    return valid_loss, valid_accuracy

# %%
''' 8. MLP 학습 실행 '''
''' 9. EPOCH 별 Test set Loss 및 Test set Accuracy 확인하기 '''
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    valid_loss, valid_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tValidation Loss: {:.4f}, \tValidation Accuracy: {:.2f} % \n".format(
        epoch, valid_loss, valid_accuracy))
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Train Loss: 2.304185
# Train Epoch: 1 [6400/50000 (13%)]	Train Loss: 2.016104
# Train Epoch: 1 [12800/50000 (26%)]	Train Loss: 1.590765
# Train Epoch: 1 [19200/50000 (38%)]	Train Loss: 1.548898
# Train Epoch: 1 [25600/50000 (51%)]	Train Loss: 1.613588
# Train Epoch: 1 [32000/50000 (64%)]	Train Loss: 2.189280
# Train Epoch: 1 [38400/50000 (77%)]	Train Loss: 1.623929
# Train Epoch: 1 [44800/50000 (90%)]	Train Loss: 1.866879
#
# [EPOCH: 1], 	Validation Loss: 0.0539, 	Validation Accuracy: 37.27 %
#
# Train Epoch: 2 [0/50000 (0%)]	Train Loss: 1.698365
# Train Epoch: 2 [6400/50000 (13%)]	Train Loss: 1.831266
# Train Epoch: 2 [12800/50000 (26%)]	Train Loss: 1.854571
# Train Epoch: 2 [19200/50000 (38%)]	Train Loss: 1.448314
# Train Epoch: 2 [25600/50000 (51%)]	Train Loss: 1.813122
# Train Epoch: 2 [32000/50000 (64%)]	Train Loss: 1.694622
# Train Epoch: 2 [38400/50000 (77%)]	Train Loss: 1.638999
# Train Epoch: 2 [44800/50000 (90%)]	Train Loss: 1.813707
#
# [EPOCH: 2], 	Validation Loss: 0.0507, 	Validation Accuracy: 42.03 %
#
# Train Epoch: 3 [0/50000 (0%)]	Train Loss: 1.299833
# Train Epoch: 3 [6400/50000 (13%)]	Train Loss: 1.524858
# Train Epoch: 3 [12800/50000 (26%)]	Train Loss: 1.401948
# Train Epoch: 3 [19200/50000 (38%)]	Train Loss: 1.519320
# Train Epoch: 3 [25600/50000 (51%)]	Train Loss: 1.705413
# Train Epoch: 3 [32000/50000 (64%)]	Train Loss: 1.159451
# Train Epoch: 3 [38400/50000 (77%)]	Train Loss: 1.450896
# Train Epoch: 3 [44800/50000 (90%)]	Train Loss: 1.498904
#
# [EPOCH: 3], 	Validation Loss: 0.0483, 	Validation Accuracy: 45.70 %
#
# Train Epoch: 4 [0/50000 (0%)]	Train Loss: 1.365912
# Train Epoch: 4 [6400/50000 (13%)]	Train Loss: 1.428482
# Train Epoch: 4 [12800/50000 (26%)]	Train Loss: 1.681912
# Train Epoch: 4 [19200/50000 (38%)]	Train Loss: 1.496556
# Train Epoch: 4 [25600/50000 (51%)]	Train Loss: 1.580008
# Train Epoch: 4 [32000/50000 (64%)]	Train Loss: 1.176908
# Train Epoch: 4 [38400/50000 (77%)]	Train Loss: 1.512969
# Train Epoch: 4 [44800/50000 (90%)]	Train Loss: 1.293974
#
# [EPOCH: 4], 	Validation Loss: 0.0481, 	Validation Accuracy: 44.57 %
#
# Train Epoch: 5 [0/50000 (0%)]	Train Loss: 1.585731
# Train Epoch: 5 [6400/50000 (13%)]	Train Loss: 1.420370
# Train Epoch: 5 [12800/50000 (26%)]	Train Loss: 1.282869
# Train Epoch: 5 [19200/50000 (38%)]	Train Loss: 1.430262
# Train Epoch: 5 [25600/50000 (51%)]	Train Loss: 1.644472
# Train Epoch: 5 [32000/50000 (64%)]	Train Loss: 1.655891
# Train Epoch: 5 [38400/50000 (77%)]	Train Loss: 1.517233
# Train Epoch: 5 [44800/50000 (90%)]	Train Loss: 1.577341
#
# [EPOCH: 5], 	Validation Loss: 0.0482, 	Validation Accuracy: 44.94 %
#
# Train Epoch: 6 [0/50000 (0%)]	Train Loss: 1.437932
# Train Epoch: 6 [6400/50000 (13%)]	Train Loss: 1.410247
# Train Epoch: 6 [12800/50000 (26%)]	Train Loss: 1.047252
# Train Epoch: 6 [19200/50000 (38%)]	Train Loss: 1.353962
# Train Epoch: 6 [25600/50000 (51%)]	Train Loss: 1.480720
# Train Epoch: 6 [32000/50000 (64%)]	Train Loss: 1.364640
# Train Epoch: 6 [38400/50000 (77%)]	Train Loss: 1.322199
# Train Epoch: 6 [44800/50000 (90%)]	Train Loss: 1.674005
#
# [EPOCH: 6], 	Validation Loss: 0.0470, 	Validation Accuracy: 46.12 %
#
# Train Epoch: 7 [0/50000 (0%)]	Train Loss: 1.063725
# Train Epoch: 7 [6400/50000 (13%)]	Train Loss: 1.713006
# Train Epoch: 7 [12800/50000 (26%)]	Train Loss: 1.159263
# Train Epoch: 7 [19200/50000 (38%)]	Train Loss: 1.525587
# Train Epoch: 7 [25600/50000 (51%)]	Train Loss: 1.473661
# Train Epoch: 7 [32000/50000 (64%)]	Train Loss: 1.444046
# Train Epoch: 7 [38400/50000 (77%)]	Train Loss: 1.543892
# Train Epoch: 7 [44800/50000 (90%)]	Train Loss: 1.445069
#
# [EPOCH: 7], 	Validation Loss: 0.0457, 	Validation Accuracy: 48.27 %
#
# Train Epoch: 8 [0/50000 (0%)]	Train Loss: 1.317993
# Train Epoch: 8 [6400/50000 (13%)]	Train Loss: 1.190515
# Train Epoch: 8 [12800/50000 (26%)]	Train Loss: 1.532524
# Train Epoch: 8 [19200/50000 (38%)]	Train Loss: 1.320389
# Train Epoch: 8 [25600/50000 (51%)]	Train Loss: 1.394020
# Train Epoch: 8 [32000/50000 (64%)]	Train Loss: 1.341225
# Train Epoch: 8 [38400/50000 (77%)]	Train Loss: 1.422212
# Train Epoch: 8 [44800/50000 (90%)]	Train Loss: 1.289122
#
# [EPOCH: 8], 	Validation Loss: 0.0462, 	Validation Accuracy: 47.80 %
#
# Train Epoch: 9 [0/50000 (0%)]	Train Loss: 1.310204
# Train Epoch: 9 [6400/50000 (13%)]	Train Loss: 1.016797
# Train Epoch: 9 [12800/50000 (26%)]	Train Loss: 1.703542
# Train Epoch: 9 [19200/50000 (38%)]	Train Loss: 1.453276
# Train Epoch: 9 [25600/50000 (51%)]	Train Loss: 1.085161
# Train Epoch: 9 [32000/50000 (64%)]	Train Loss: 1.670373
# Train Epoch: 9 [38400/50000 (77%)]	Train Loss: 1.431597
# Train Epoch: 9 [44800/50000 (90%)]	Train Loss: 1.549783
#
# [EPOCH: 9], 	Validation Loss: 0.0464, 	Validation Accuracy: 47.93 %
#
# Train Epoch: 10 [0/50000 (0%)]	Train Loss: 1.404676
# Train Epoch: 10 [6400/50000 (13%)]	Train Loss: 1.791972
# Train Epoch: 10 [12800/50000 (26%)]	Train Loss: 1.262457
# Train Epoch: 10 [19200/50000 (38%)]	Train Loss: 1.467469
# Train Epoch: 10 [25600/50000 (51%)]	Train Loss: 1.581567
# Train Epoch: 10 [32000/50000 (64%)]	Train Loss: 1.488850
# Train Epoch: 10 [38400/50000 (77%)]	Train Loss: 1.324542
# Train Epoch: 10 [44800/50000 (90%)]	Train Loss: 1.630266
#
# [EPOCH: 10], 	Validation Loss: 0.0443, 	Validation Accuracy: 50.21 %
