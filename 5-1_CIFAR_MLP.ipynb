# %%
''' 1. 모듈 임포트 '''
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms, datasets

# %%
''' 2. 딥러닝 모델을 설계할 때 활용하는 장비 확인 '''
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')

print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 1.5.0+cu101  Device: cuda

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %%
''' 3. CIFAR10 데이터 다운로드 '''
train_dataset = datasets.CIFAR10(root = "../data/CIFAR_10",
                                  train = True,
                                  download = True,
                                  transform = transforms.ToTensor())

test_dataset = datasets.CIFAR10(root = "../data/CIFAR_10",
                                train = False,
                                transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                            batch_size = BATCH_SIZE,
                                            shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/CIFAR_10/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../data/CIFAR_10/cifar-10-python.tar.gz to ../data/CIFAR_10

# %%
''' 4. 데이터 확인하기 (1) '''
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 3, 32, 32]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
''' 4. 데이터 확인하기 (2) '''
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))

for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(np.transpose(X_train[i], (1, 2, 0)))
    plt.title('Class: ' + str(y_train[i].item()))

# %%
''' 5. MLP (Multi Layer Perceptron) 모델 설계하기 '''
class Net(nn.Module):                            
    def __init__(self):                          
        super(Net, self).__init__()              
        self.fc1 = nn.Linear(32 * 32 * 3, 512)   
        self.fc2 = nn.Linear(512, 256)           
        self.fc3 = nn.Linear(256, 10)            
    
    def forward(self, x):                        
        x = x.view(-1, 32 * 32 * 3)              
        x = self.fc1(x)                          
        x = F.relu(x)                            
        x = self.fc2(x)                          
        x = F.relu(x)                            
        x = self.fc3(x)                          
        x = F.log_softmax(x, dim = 1)            
        return x

# %%
''' 6. Optimizer, Objective Function 설정하기 '''
model = Net().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=3072, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
''' 7. MLP 학습, Test 성능 확인하는 함수 정의 '''
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image), 
                len(train_loader.dataset), 100. * batch_idx / len(train_loader), 
                loss.item()))

# %%
def evaluate(model, valid_loader):
    model.eval()
    valid_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in valid_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            valid_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    
    valid_loss /= len(valid_loader.dataset)
    valid_accuracy = 100. * correct / len(valid_loader.dataset)
    return valid_loss, valid_accuracy

# %%
''' 8. MLP 학습 실행 '''
''' 9. EPOCH 별 Test set Loss 및 Test set Accuracy 확인하기 '''
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    valid_loss, valid_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tValidation Loss: {:.4f}, \tValidation Accuracy: {:.2f} % \n".format(
        epoch, valid_loss, valid_accuracy))
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Train Loss: 2.311756
# Train Epoch: 1 [6400/50000 (13%)]	Train Loss: 2.180797
# Train Epoch: 1 [12800/50000 (26%)]	Train Loss: 1.688089
# Train Epoch: 1 [19200/50000 (38%)]	Train Loss: 2.015209
# Train Epoch: 1 [25600/50000 (51%)]	Train Loss: 1.877581
# Train Epoch: 1 [32000/50000 (64%)]	Train Loss: 1.886130
# Train Epoch: 1 [38400/50000 (77%)]	Train Loss: 1.697324
# Train Epoch: 1 [44800/50000 (90%)]	Train Loss: 1.486631
#
# [EPOCH: 1], 	Validation Loss: 0.0536, 	Validation Accuracy: 37.67 %
#
# Train Epoch: 2 [0/50000 (0%)]	Train Loss: 1.638863
# Train Epoch: 2 [6400/50000 (13%)]	Train Loss: 1.755984
# Train Epoch: 2 [12800/50000 (26%)]	Train Loss: 1.832520
# Train Epoch: 2 [19200/50000 (38%)]	Train Loss: 1.704204
# Train Epoch: 2 [25600/50000 (51%)]	Train Loss: 1.645787
# Train Epoch: 2 [32000/50000 (64%)]	Train Loss: 1.749298
# Train Epoch: 2 [38400/50000 (77%)]	Train Loss: 1.786396
# Train Epoch: 2 [44800/50000 (90%)]	Train Loss: 1.694422
#
# [EPOCH: 2], 	Validation Loss: 0.0527, 	Validation Accuracy: 40.82 %
#
# Train Epoch: 3 [0/50000 (0%)]	Train Loss: 1.569714
# Train Epoch: 3 [6400/50000 (13%)]	Train Loss: 1.342723
# Train Epoch: 3 [12800/50000 (26%)]	Train Loss: 1.628362
# Train Epoch: 3 [19200/50000 (38%)]	Train Loss: 1.568157
# Train Epoch: 3 [25600/50000 (51%)]	Train Loss: 1.611073
# Train Epoch: 3 [32000/50000 (64%)]	Train Loss: 1.439365
# Train Epoch: 3 [38400/50000 (77%)]	Train Loss: 1.777572
# Train Epoch: 3 [44800/50000 (90%)]	Train Loss: 1.501148
#
# [EPOCH: 3], 	Validation Loss: 0.0492, 	Validation Accuracy: 43.24 %
#
# Train Epoch: 4 [0/50000 (0%)]	Train Loss: 1.340954
# Train Epoch: 4 [6400/50000 (13%)]	Train Loss: 1.312045
# Train Epoch: 4 [12800/50000 (26%)]	Train Loss: 1.577855
# Train Epoch: 4 [19200/50000 (38%)]	Train Loss: 1.640025
# Train Epoch: 4 [25600/50000 (51%)]	Train Loss: 1.226549
# Train Epoch: 4 [32000/50000 (64%)]	Train Loss: 1.624370
# Train Epoch: 4 [38400/50000 (77%)]	Train Loss: 1.631144
# Train Epoch: 4 [44800/50000 (90%)]	Train Loss: 1.627759
#
# [EPOCH: 4], 	Validation Loss: 0.0484, 	Validation Accuracy: 44.07 %
#
# Train Epoch: 5 [0/50000 (0%)]	Train Loss: 1.590184
# Train Epoch: 5 [6400/50000 (13%)]	Train Loss: 1.413497
# Train Epoch: 5 [12800/50000 (26%)]	Train Loss: 1.239363
# Train Epoch: 5 [19200/50000 (38%)]	Train Loss: 1.658287
# Train Epoch: 5 [25600/50000 (51%)]	Train Loss: 1.552002
# Train Epoch: 5 [32000/50000 (64%)]	Train Loss: 1.627394
# Train Epoch: 5 [38400/50000 (77%)]	Train Loss: 1.362456
# Train Epoch: 5 [44800/50000 (90%)]	Train Loss: 1.629866
#
# [EPOCH: 5], 	Validation Loss: 0.0473, 	Validation Accuracy: 45.75 %
#
# Train Epoch: 6 [0/50000 (0%)]	Train Loss: 1.598037
# Train Epoch: 6 [6400/50000 (13%)]	Train Loss: 1.526649
# Train Epoch: 6 [12800/50000 (26%)]	Train Loss: 1.307356
# Train Epoch: 6 [19200/50000 (38%)]	Train Loss: 1.810354
# Train Epoch: 6 [25600/50000 (51%)]	Train Loss: 1.237015
# Train Epoch: 6 [32000/50000 (64%)]	Train Loss: 1.511431
# Train Epoch: 6 [38400/50000 (77%)]	Train Loss: 1.747253
# Train Epoch: 6 [44800/50000 (90%)]	Train Loss: 1.376653
#
# [EPOCH: 6], 	Validation Loss: 0.0473, 	Validation Accuracy: 45.50 %
#
# Train Epoch: 7 [0/50000 (0%)]	Train Loss: 1.571659
# Train Epoch: 7 [6400/50000 (13%)]	Train Loss: 1.479286
# Train Epoch: 7 [12800/50000 (26%)]	Train Loss: 1.490709
# Train Epoch: 7 [19200/50000 (38%)]	Train Loss: 1.409930
# Train Epoch: 7 [25600/50000 (51%)]	Train Loss: 1.527570
# Train Epoch: 7 [32000/50000 (64%)]	Train Loss: 1.612086
# Train Epoch: 7 [38400/50000 (77%)]	Train Loss: 1.391174
# Train Epoch: 7 [44800/50000 (90%)]	Train Loss: 1.272004
#
# [EPOCH: 7], 	Validation Loss: 0.0462, 	Validation Accuracy: 47.27 %
#
# Train Epoch: 8 [0/50000 (0%)]	Train Loss: 1.276796
# Train Epoch: 8 [6400/50000 (13%)]	Train Loss: 1.272708
# Train Epoch: 8 [12800/50000 (26%)]	Train Loss: 1.524567
# Train Epoch: 8 [19200/50000 (38%)]	Train Loss: 1.229108
# Train Epoch: 8 [25600/50000 (51%)]	Train Loss: 1.647481
# Train Epoch: 8 [32000/50000 (64%)]	Train Loss: 1.405079
# Train Epoch: 8 [38400/50000 (77%)]	Train Loss: 1.229187
# Train Epoch: 8 [44800/50000 (90%)]	Train Loss: 1.405201
#
# [EPOCH: 8], 	Validation Loss: 0.0457, 	Validation Accuracy: 47.91 %
#
# Train Epoch: 9 [0/50000 (0%)]	Train Loss: 1.275303
# Train Epoch: 9 [6400/50000 (13%)]	Train Loss: 1.838737
# Train Epoch: 9 [12800/50000 (26%)]	Train Loss: 1.407662
# Train Epoch: 9 [19200/50000 (38%)]	Train Loss: 1.232621
# Train Epoch: 9 [25600/50000 (51%)]	Train Loss: 1.185524
# Train Epoch: 9 [32000/50000 (64%)]	Train Loss: 1.121307
# Train Epoch: 9 [38400/50000 (77%)]	Train Loss: 1.139901
# Train Epoch: 9 [44800/50000 (90%)]	Train Loss: 1.334594
#
# [EPOCH: 9], 	Validation Loss: 0.0446, 	Validation Accuracy: 49.58 %
#
# Train Epoch: 10 [0/50000 (0%)]	Train Loss: 1.462472
# Train Epoch: 10 [6400/50000 (13%)]	Train Loss: 1.597817
# Train Epoch: 10 [12800/50000 (26%)]	Train Loss: 1.473222
# Train Epoch: 10 [19200/50000 (38%)]	Train Loss: 1.273536
# Train Epoch: 10 [25600/50000 (51%)]	Train Loss: 1.463260
# Train Epoch: 10 [32000/50000 (64%)]	Train Loss: 1.384786
# Train Epoch: 10 [38400/50000 (77%)]	Train Loss: 1.264640
# Train Epoch: 10 [44800/50000 (90%)]	Train Loss: 1.231224
#
# [EPOCH: 10], 	Validation Loss: 0.0451, 	Validation Accuracy: 48.94 %
